# %% [markdown]
# Hi, this notebook has been created to complete the Capstone project and fulfill all the required assignments and tasks

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone project course!")
# Out:
# Hello Capstone project course!
